# %%
import pandas as pd

# %%
df0 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=0)
df1 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=1)
df2 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=2)
df3 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=3)
df4 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=4)
df5 = pd.read_excel("data/FinalMarksDataset.xlsx", sheet_name=5)

# %%
df0
# Out:
#     Unnamed: 0       As:1        As:2       As:3   As:4        As:5  \
# 0            1  61.923077   86.428571  81.666667   81.0   49.166667
# 1            2  55.769231   97.142857  43.333333   70.0   67.083333
# 2            3  86.923077   88.571429   0.000000   94.0   66.666667
# 3            4  46.923077   62.142857   0.000000   44.0    0.000000
# 4            5  80.000000   95.714286  80.555556   90.0  100.000000
# 5            6   0.000000   74.285714  67.777778   41.0   45.833333
# 6            7  90.769231   88.571429  95.000000   79.0   90.833333
# 7            8   0.000000   67.142857  48.888889   46.0   42.500000
# 8            9  80.769231   92.857143  75.000000   94.0   77.500000
# 9           10  86.923077   84.285714  57.222222   66.0   55.000000
# 10          11   0.000000   93.571429  67.222222   56.0   51.666667
# 11          12  80.769231   85.714286  43.888889  100.0   66.666667
# 12          13  70.769231   72.857143   0.000000   70.0   70.833333
# 13          14  93.846154   77.857143  87.777778   70.0   75.000000
# 14          15  83.846154    0.000000  83.888889   66.0   83.333333
# 15          16   0.000000   88.571429  87.777778  100.0   73.333333
# 16          17   0.000000   90.714286  94.444444  100.0   80.000000
# 17          18  80.000000    0.000000   0.000000   99.0   78.333333
# 18          19  79.230769    0.000000  88.888889  100.0   91.666667
# 19          20  56.538462   76.428571  72.222222   74.0   75.000000
# 20          21  83.076923   63.571429  55.555556   87.0   66.666667
# 21          22  82.307692   80.000000  91.666667   94.0   33.333333
# 22          23  91.538462   60.000000  80.000000   92.0   90.000000
# 23          24  57.692308    0.000000   0.000000   30.0   72.500000
# 24          25  79.230769   74.285714  66.666667   42.0   54.583333
# 25          26  43.461538    0.000000  67.777778   51.0   49.166667
# 26          27  84.615385   76.428571  78.333333   60.0   50.833333
# 27          28  68.461538   57.142857  36.111111   67.0   45.000000
# 28          29  70.769231  100.000000  91.111111   85.0    0.000000
# 29          30  77.692308   70.714286   0.000000   95.0   73.333333
# 30          31  47.692308    0.000000  63.333333   60.0   72.500000
# 31          32  64.615385   72.857143  49.444444   56.0   66.666667
# 32          33  96.153846   85.714286  93.333333   81.0   91.666667
# 33          34  74.615385    0.000000  55.555556   82.0   60.000000
#
#           As:6  Qz:1       Qz:2   Qz:3  Qz:4  Qz:5  Qz:6        Qz:7  Qz:8  \
# 0    78.333333    70  33.333333   20.0    80     0    50   75.000000   100
# 1    78.888889    50  46.666667    0.0   100    70   100   83.333333   100
# 2    88.888889    70  16.666667   10.0    10    20    20  100.000000   100
# 3    55.555556    30  33.333333    5.0     0     0    20   25.000000     0
# 4   100.000000   100  70.000000  100.0   100    65   100   75.000000   100
# 5    64.444444    90  36.666667   15.0     0    80    80   25.000000   100
# 6   100.000000   100  56.666667   95.0   100    70    90   83.333333   100
# 7     0.000000    40  40.000000    5.0     0    10     0   25.000000     0
# 8    96.666667    70  56.666667    0.0    10    10    40   75.000000   100
# 9    54.444444    90  13.333333    5.0     0     0    30   16.666667   100
# 10   81.111111    50  43.333333   90.0   100   100    70   66.666667   100
# 11   98.888889     0  13.333333   55.0    10    10    30   58.333333   100
# 12   80.000000    50  36.666667   15.0    10    10    40    8.333333   100
# 13    0.000000    70  36.666667    0.0    10    10    90   33.333333   100
# 14   97.777778    60  30.000000   60.0     0    10    70   16.666667   100
# 15  100.000000    80  46.666667    0.0   100    30    80   33.333333   100
# 16   36.666667   100  26.666667   40.0   100    30    80   33.333333   100
# 17   88.888889    90  20.000000   95.0    10     0   100   50.000000   100
# 18  100.000000    80  60.000000  100.0   100    20   100    0.000000   100
# 19   58.888889    30  13.333333    5.0     0    10    70   16.666667   100
# 20   60.000000   100   0.000000   40.0    10    15    80   75.000000   100
# 21   72.222222   100  60.000000   95.0   100   100    90   83.333333   100
# 22   88.888889    90  53.333333   15.0     5    30    70   66.666667   100
# 23    0.000000    50  40.000000   10.0     0    20     0    0.000000     0
# 24   87.777778    90  60.000000   10.0     0    30    70   75.000000   100
# 25   78.888889    70  20.000000   20.0     0    20    70   33.333333   100
# 26   81.111111    70  56.666667   10.0   100    50    50   41.666667   100
# 27   54.444444    60  23.333333    0.0     0    30    40   25.000000   100
# 28   93.888889    80  46.666667   30.0     0    80    80   25.000000   100
# 29   51.111111    60  56.666667    5.0     0    10    40   16.666667   100
# 30   74.444444     0  66.666667    0.0    10    30     0   50.000000   100
# 31   53.333333    40  46.666667   10.0     0    90    60   58.333333   100
# 32   95.555556    90  40.000000    0.0     0    30    50   16.666667   100
# 33    0.000000     0  30.000000    0.0     0    30     0    0.000000   100
#
#           S-I       S-II      Final
# 0   43.733333  15.600000  35.733333
# 1   31.200000  27.466667  53.488889
# 2   23.733333  16.200000  32.488889
# 3   46.200000  22.466667  28.000000
# 4   71.200000  43.733333  74.733333
# 5   26.200000  10.000000  39.488889
# 6   56.866667  34.333333  70.488889
# 7   16.200000  12.466667  13.244444
# 8   35.000000  60.600000  58.244444
# 9   22.466667  11.866667  27.733333
# 10  36.866667  43.733333  60.488889
# 11  38.733333  15.600000  40.000000
# 12  46.200000  40.600000  47.488889
# 13  35.000000  14.333333  45.733333
# 14  37.466667  12.466667  47.244444
# 15  38.733333  35.000000  61.244444
# 16  53.733333  73.733333  49.244444
# 17  47.466667  46.200000  65.244444
# 18  73.733333  48.066667  63.733333
# 19  36.200000  27.466667  44.488889
# 20  53.733333  42.466667  45.488889
# 21  73.066667  54.333333  64.000000
# 22  47.466667  46.200000  66.488889
# 23  31.200000   5.000000  14.000000
# 24  48.733333  36.866667  58.733333
# 25  30.000000  33.066667  35.733333
# 26  33.733333  16.200000  43.488889
# 27  28.733333  10.600000  43.488889
# 28  29.333333  28.733333  40.000000
# 29  43.733333  19.333333  24.244444
# 30  22.466667  10.600000  27.733333
# 31  35.000000  10.000000  36.244444
# 32  53.733333  28.733333  50.733333
# 33  29.333333   9.333333  14.488889

# %%
df = pd.concat([df0,df1,df2,df3,df4,df5])

# %%
df["Final"].corr(df["S-I"])
# Out:
# np.float64(0.5530821495256625)

# %%
df
# Out:
#     Unnamed: 0       As:1       As:2       As:3   As:4        As:5  \
# 0            1  61.923077  86.428571  81.666667  81.00   49.166667
# 1            2  55.769231  97.142857  43.333333  70.00   67.083333
# 2            3  86.923077  88.571429   0.000000  94.00   66.666667
# 3            4  46.923077  62.142857   0.000000  44.00    0.000000
# 4            5  80.000000  95.714286  80.555556  90.00  100.000000
# ..         ...        ...        ...        ...    ...         ...
# 46          47   0.000000   0.000000   0.000000   0.00         NaN
# 47          48  70.500000  76.666667  73.000000  76.25         NaN
# 48          49  41.500000   0.000000  88.000000  90.00         NaN
# 49          50  32.000000  80.000000  77.000000  82.50         NaN
# 50          51  43.500000   0.000000  75.000000  88.75         NaN
#
#           As:6   Qz:1       Qz:2    Qz:3   Qz:4  Qz:5   Qz:6        Qz:7  \
# 0    78.333333   70.0  33.333333   20.00   80.0   0.0   50.0   75.000000
# 1    78.888889   50.0  46.666667    0.00  100.0  70.0  100.0   83.333333
# 2    88.888889   70.0  16.666667   10.00   10.0  20.0   20.0  100.000000
# 3    55.555556   30.0  33.333333    5.00    0.0   0.0   20.0   25.000000
# 4   100.000000  100.0  70.000000  100.00  100.0  65.0  100.0   75.000000
# ..         ...    ...        ...     ...    ...   ...    ...         ...
# 46         NaN   50.0   0.000000   18.75    0.0   0.0    0.0         NaN
# 47         NaN   15.0  70.000000   37.50    0.0  10.0   40.0         NaN
# 48         NaN   60.0  20.000000   37.50    0.0   0.0   30.0         NaN
# 49         NaN    0.0   0.000000   43.75   60.0  25.0    0.0         NaN
# 50         NaN    0.0  20.000000   18.75   20.0   5.0   40.0         NaN
#
#      Qz:8        S-I       S-II      Final  Proj
# 0   100.0  43.733333  15.600000  35.733333   NaN
# 1   100.0  31.200000  27.466667  53.488889   NaN
# 2   100.0  23.733333  16.200000  32.488889   NaN
# 3     0.0  46.200000  22.466667  28.000000   NaN
# 4   100.0  71.200000  43.733333  74.733333   NaN
# ..    ...        ...        ...        ...   ...
# 46    NaN  49.133333  18.133333  23.133333   NaN
# 47    NaN  55.000000  47.200000  62.822222   NaN
# 48    NaN  57.466667  37.200000  51.488889   NaN
# 49    NaN  47.466667  54.466667  53.733333   NaN
# 50    NaN  43.333333  51.733333  52.311111   NaN
#
# [254 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'As:1', 'As:2', 'As:3', 'As:4', 'As:5', 'As:6', 'Qz:1',
#        'Qz:2', 'Qz:3', 'Qz:4', 'Qz:5', 'Qz:6', 'Qz:7', 'Qz:8', 'S-I', 'S-II',
#        'Final', 'Proj'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#          As:1       As:2       As:3   As:4        As:5        As:6   Qz:1  \
# 0   61.923077  86.428571  81.666667  81.00   49.166667   78.333333   70.0
# 1   55.769231  97.142857  43.333333  70.00   67.083333   78.888889   50.0
# 2   86.923077  88.571429   0.000000  94.00   66.666667   88.888889   70.0
# 3   46.923077  62.142857   0.000000  44.00    0.000000   55.555556   30.0
# 4   80.000000  95.714286  80.555556  90.00  100.000000  100.000000  100.0
# ..        ...        ...        ...    ...         ...         ...    ...
# 46   0.000000   0.000000   0.000000   0.00         NaN         NaN   50.0
# 47  70.500000  76.666667  73.000000  76.25         NaN         NaN   15.0
# 48  41.500000   0.000000  88.000000  90.00         NaN         NaN   60.0
# 49  32.000000  80.000000  77.000000  82.50         NaN         NaN    0.0
# 50  43.500000   0.000000  75.000000  88.75         NaN         NaN    0.0
#
#          Qz:2    Qz:3   Qz:4  Qz:5   Qz:6        Qz:7   Qz:8        S-I  \
# 0   33.333333   20.00   80.0   0.0   50.0   75.000000  100.0  43.733333
# 1   46.666667    0.00  100.0  70.0  100.0   83.333333  100.0  31.200000
# 2   16.666667   10.00   10.0  20.0   20.0  100.000000  100.0  23.733333
# 3   33.333333    5.00    0.0   0.0   20.0   25.000000    0.0  46.200000
# 4   70.000000  100.00  100.0  65.0  100.0   75.000000  100.0  71.200000
# ..        ...     ...    ...   ...    ...         ...    ...        ...
# 46   0.000000   18.75    0.0   0.0    0.0         NaN    NaN  49.133333
# 47  70.000000   37.50    0.0  10.0   40.0         NaN    NaN  55.000000
# 48  20.000000   37.50    0.0   0.0   30.0         NaN    NaN  57.466667
# 49   0.000000   43.75   60.0  25.0    0.0         NaN    NaN  47.466667
# 50  20.000000   18.75   20.0   5.0   40.0         NaN    NaN  43.333333
#
#          S-II      Final  Proj
# 0   15.600000  35.733333   NaN
# 1   27.466667  53.488889   NaN
# 2   16.200000  32.488889   NaN
# 3   22.466667  28.000000   NaN
# 4   43.733333  74.733333   NaN
# ..        ...        ...   ...
# 46  18.133333  23.133333   NaN
# 47  47.200000  62.822222   NaN
# 48  37.200000  51.488889   NaN
# 49  54.466667  53.733333   NaN
# 50  51.733333  52.311111   NaN
#
# [254 rows x 18 columns]

# %%
df.describe()
# Out:
#              As:1        As:2        As:3        As:4        As:5        As:6  \
# count  254.000000  254.000000  254.000000  254.000000  152.000000   62.000000
# mean    56.766244   59.902231   64.694335   60.935499   61.901042   68.142921
# std     28.112890   31.761446   26.459035   32.502959   31.665489   29.631618
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     38.000000   51.500000   53.250000   44.250000   49.166667   56.354167
# 50%     61.500000   72.250000   71.833333   70.000000   70.416667   76.388889
# 75%     80.769231   82.000000   84.166667   86.916667   87.500000   88.888889
# max     99.000000  100.000000   99.166667  100.000000  100.000000  100.000000
#
#              Qz:1        Qz:2        Qz:3        Qz:4        Qz:5        Qz:6  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000  254.000000
# mean    46.318898   34.140420   42.244094   39.718898   36.948819   43.110236
# std     31.184341   28.828967   28.025582   33.145941   30.678128   31.603579
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     16.250000   10.000000   20.000000   10.000000   10.000000   10.000000
# 50%     50.000000   30.000000   43.750000   35.000000   30.000000   40.000000
# 75%     70.000000   50.000000   60.000000   60.000000   60.000000   70.000000
# max    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#              Qz:7        Qz:8         S-I        S-II       Final       Proj
# count  152.000000   62.000000  254.000000  254.000000  254.000000  44.000000
# mean    41.584430   93.548387   44.794751   38.767192   44.245801  55.212121
# std     29.327726   24.767560   17.175087   22.057860   19.122385  29.396346
# min      0.000000    0.000000    3.733333    0.000000    5.450000   0.000000
# 25%     19.791667  100.000000   31.666667   20.950000   31.743750  38.750000
# 50%     41.666667  100.000000   45.000000   35.800000   43.444444  65.000000
# 75%     58.333333  100.000000   56.200000   54.466667   57.277778  76.250000
# max    100.000000  100.000000   93.333333  100.000000   91.755556  95.000000

# %%
df["Final"].corr(df["S-I"])
# Out:
# np.float64(0.5530821495256625)

# %%
df["Final"].corr(df["S-II"])
# Out:
# np.float64(0.7830528752686216)

# %%
df["Final"].corr(df["S-I"] + df["S-II"])
# Out:
# np.float64(0.7484836039905911)

# %%
df.to_csv('data/final_dataset.csv')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score, mean_squared_error, mean_absolute_error
)

# --------------------------
# 1. SPLIT DATA
# --------------------------
X = df[["S-I", "S-II"]]
y = df["Final"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 2. TRAIN MULTIPLE LINEAR REGRESSION
# --------------------------
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# --------------------------
# 3. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1-r2)*(n-1)/(n-k-1))

# Model metrics
r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("----- Multiple Linear Regression -----")
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print(f"R²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 4. CONSTANT MODEL BASELINE
# --------------------------

# Predict mean of training set
constant_pred = np.full_like(y_test, y_train.mean())

r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 5. VISUALIZATION
# --------------------------

# Pairplot of predictors vs Final
sns.pairplot(df[["S-I", "S-II", "Final"]], kind="reg")
plt.show()

# Scatter plot + prediction plane (2D projections)
plt.figure(figsize=(6,4))
sns.scatterplot(x=df["S-I"], y=df["Final"])
sns.regplot(x=df["S-I"], y=df["Final"], scatter=False, color="red")
plt.title("S-I vs Final")
plt.show()

plt.figure(figsize=(6,4))
sns.scatterplot(x=df["S-II"], y=df["Final"])
sns.regplot(x=df["S-II"], y=df["Final"], scatter=False, color="red")
plt.title("S-II vs Final")
plt.show()

# Actual vs Predicted scatter
plt.figure(figsize=(6,4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final Scores")
plt.ylabel("Predicted Final Scores")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# ----- Multiple Linear Regression -----
# Coefficients: [0.09036606 0.62067878]
# Intercept: 15.812490246147881
# R²: 0.5903
# Adjusted R²: 0.5546
# RMSE: 13.2036
# MAE: 10.7977
# MAPE: 39.70%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
df.columns
# Out:
# Index(['As:1', 'As:2', 'As:3', 'As:4', 'As:5', 'As:6', 'Qz:1', 'Qz:2', 'Qz:3',
#        'Qz:4', 'Qz:5', 'Qz:6', 'Qz:7', 'Qz:8', 'S-I', 'S-II', 'Final', 'Proj'],
#       dtype='object')

# %%
null_cols = [i for i in df.columns if df[i].isnull().any()] 
for i in null_cols:
    print(i,df[i].isnull().sum())
# Out:
# As:5 102
# As:6 192
# Qz:7 102
# Qz:8 192
# Proj 210

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score, mean_squared_error, mean_absolute_error
)

# ------------------------------------------------
# 1. SELECT COLUMNS (REMOVE As:5, As:6, Qz:7, Qz:8, Proj, Final)
# ------------------------------------------------

cols_to_use = [
    'As:1','As:2','As:3','As:4',
    'Qz:1','Qz:2','Qz:3','Qz:4','Qz:5','Qz:6',
    'S-I','S-II'
]

X = df[cols_to_use]
y = df["Final"]

# ------------------------------------------------
# 2. TRAIN-TEST SPLIT (90% / 10%)
# ------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# ------------------------------------------------
# 3. MULTIPLE LINEAR REGRESSION MODEL
# ------------------------------------------------

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# ------------------------------------------------
# 4. METRICS
# ------------------------------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1-r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("\n----- Multiple Linear Regression (Full Model) -----")
print("Intercept:", model.intercept_)
print("\nCoefficients:")
for col, coef in zip(cols_to_use, model.coef_):
    print(f"{col}: {coef:.4f}")

print(f"\nR²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# ------------------------------------------------
# 5. CONSTANT BASELINE MODEL
# ------------------------------------------------

constant_pred = np.full_like(y_test, y_train.mean())

r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# ------------------------------------------------
# 6. VISUALIZATIONS
# ------------------------------------------------

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Pairplot: predictors vs Final
sns.pairplot(df[cols_to_use + ["Final"]], diag_kind="kde")
plt.show()

# Actual vs predicted scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# ----- Multiple Linear Regression (Full Model) -----
# Intercept: 10.885609201654553
#
# Coefficients:
# As:1: -0.0453
# As:2: 0.0095
# As:3: 0.0494
# As:4: 0.1101
# Qz:1: 0.0253
# Qz:2: -0.0599
# Qz:3: -0.0714
# Qz:4: -0.0070
# Qz:5: 0.0090
# Qz:6: 0.0723
# S-I: 0.1123
# S-II: 0.5416
#
# R²: 0.7105
# Adjusted R²: 0.4433
# RMSE: 11.0983
# MAE: 9.2426
# MAPE: 29.80%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    r2_score, mean_squared_error, mean_absolute_error
)

# ------------------------------------------------
# 1. CREATE NEW MEAN COLUMNS
# ------------------------------------------------

df["As_Mean"] = df[["As:1", "As:2", "As:3", "As:4"]].median(axis=1)
df["Qz_Mean"] = df[["Qz:1", "Qz:2", "Qz:3", "Qz:4", "Qz:5", "Qz:6"]].median(axis=1)

# ------------------------------------------------
# 2. SELECT FEATURES
# ------------------------------------------------

cols_to_use = ["As_Mean", "Qz_Mean", "S-I", "S-II"]

X = df[cols_to_use]
y = df["Final"]

# ------------------------------------------------
# 3. TRAIN-TEST SPLIT (90/10)
# ------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# ------------------------------------------------
# 4. MULTIPLE LINEAR REGRESSION MODEL
# ------------------------------------------------

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# ------------------------------------------------
# 5. METRICS
# ------------------------------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1-r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("\n----- Multiple Linear Regression (Collapsed Predictors) -----")
print("Intercept:", model.intercept_)
print("\nCoefficients:")
for col, coef in zip(cols_to_use, model.coef_):
    print(f"{col}: {coef:.4f}")

print(f"\nR²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# ------------------------------------------------
# 6. BASELINE MODEL
# ------------------------------------------------

constant_pred = np.full_like(y_test, y_train.mean())

r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# ------------------------------------------------
# 7. VISUALIZATIONS
# ------------------------------------------------

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Pairplot
sns.pairplot(df[cols_to_use + ["Final"]], diag_kind="kde")
plt.show()

# Actual vs Predicted
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# ----- Multiple Linear Regression (Collapsed Predictors) -----
# Intercept: 10.790228201597571
#
# Coefficients:
# As_Mean: 0.1087
# Qz_Mean: -0.0220
# S-I: 0.0863
# S-II: 0.5957
#
# R²: 0.6218
# Adjusted R²: 0.5498
# RMSE: 12.6847
# MAE: 10.3115
# MAPE: 38.23%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# --------------------------
# 1. REPLACE MISSING VALUES
# --------------------------

# Assignments
as_mean = df[["As:1", "As:2", "As:3", "As:4"]].mean(axis=1)
df["As:5"] = df["As:5"].fillna(as_mean)
df["As:6"] = df["As:6"].fillna(as_mean)

# Quizzes
qz_mean = df[["Qz:1", "Qz:2", "Qz:3", "Qz:4", "Qz:5", "Qz:6"]].mean(axis=1)
df["Qz:7"] = df["Qz:7"].fillna(qz_mean)
df["Qz:8"] = df["Qz:8"].fillna(qz_mean)

# --------------------------
# 2. SELECT RAW FEATURES
# --------------------------

cols_to_use = [
    "As:1","As:2","As:3","As:4","As:5","As:6",
    "Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6","Qz:7","Qz:8",
    "S-I","S-II"
]

X = df[cols_to_use]
y = df["Final"]

# --------------------------
# 3. TRAIN-TEST SPLIT (90/10)
# --------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 4. MULTIPLE LINEAR REGRESSION
# --------------------------

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# --------------------------
# 5. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1 - r2) * (n - 1) / (n - k - 1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("\n----- Multiple Linear Regression (Raw Columns, Imputed) -----")
print("Intercept:", model.intercept_)
print("\nCoefficients:")
for col, coef in zip(cols_to_use, model.coef_):
    print(f"{col}: {coef:.4f}")

print(f"\nR²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 6. CONSTANT BASELINE MODEL
# --------------------------

constant_pred = np.full_like(y_test, y_train.mean())

r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 7. VISUALIZATIONS
# --------------------------

# Correlation heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# Actual vs Predicted scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# ----- Multiple Linear Regression (Raw Columns, Imputed) -----
# Intercept: 9.666071228478579
#
# Coefficients:
# As:1: -0.0613
# As:2: -0.0140
# As:3: 0.0291
# As:4: 0.0763
# As:5: 0.0140
# As:6: 0.0902
# Qz:1: 0.0173
# Qz:2: -0.0686
# Qz:3: -0.0687
# Qz:4: -0.0115
# Qz:5: 0.0066
# Qz:6: 0.0729
# Qz:7: 0.0464
# Qz:8: 0.0013
# S-I: 0.1096
# S-II: 0.5300
#
# R²: 0.7454
# Adjusted R²: 0.2928
# RMSE: 10.4076
# MAE: 8.4575
# MAPE: 25.51%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# --------------------------
# 1. SELECT FEATURES
# --------------------------

cols_to_use = [
    "As:1","As:2","As:3","As:4","As:5","As:6",
    "Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6","Qz:7","Qz:8",
    "S-I","S-II"
]

X = df[cols_to_use]
y = df["Final"]

# --------------------------
# 2. TRAIN-TEST SPLIT (90/10)
# --------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 3. POLYNOMIAL FEATURES
# --------------------------

poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# --------------------------
# 4. LINEAR REGRESSION ON POLYNOMIAL FEATURES
# --------------------------

model = LinearRegression()
model.fit(X_train_poly, y_train)
y_pred = model.predict(X_test_poly)

# --------------------------
# 5. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1 - r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test_poly.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print("\n----- Polynomial Regression (Degree 2) -----")
print(f"Number of Features after polynomial expansion: {X_train_poly.shape[1]}")
print(f"R²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 6. BASELINE MODEL
# --------------------------

constant_pred = np.full_like(y_test, y_train.mean())
r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 7. VISUALIZATION: Actual vs Predicted
# --------------------------

plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Polynomial Regression: Actual vs Predicted")
plt.show()
# Out:
# ----- Polynomial Regression (Degree 2) -----
# Number of Features after polynomial expansion: 152
# R²: -5.4355
# Adjusted R²: 2.2668
# RMSE: 52.3269
# MAE: 25.1677
# MAPE: 136.95%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# --------------------------
# 1. IMPUTE MISSING VALUES
# --------------------------

# Assignments
as_mean_raw = df[["As:1", "As:2", "As:3", "As:4"]].mean(axis=1)
df["As:5"] = df["As:5"].fillna(as_mean_raw)
df["As:6"] = df["As:6"].fillna(as_mean_raw)

# Quizzes
qz_mean_raw = df[["Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6"]].mean(axis=1)
df["Qz:7"] = df["Qz:7"].fillna(qz_mean_raw)
df["Qz:8"] = df["Qz:8"].fillna(qz_mean_raw)

# --------------------------
# 2. CREATE SUMMARY COLUMNS
# --------------------------

df["As_Mean"] = df[["As:1","As:2","As:3","As:4"]].mean(axis=1)
df["Qz_Mean"] = df[["Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6"]].mean(axis=1)

# --------------------------
# 3. SELECT PREDICTORS
# --------------------------

cols_to_use = ["As_Mean", "Qz_Mean", "S-I", "S-II"]

X = df[cols_to_use]
y = df["Final"]

# --------------------------
# 4. TRAIN-TEST SPLIT
# --------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 5. FIT MULTIPLE LINEAR REGRESSION
# --------------------------

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# --------------------------
# 6. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1 - r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred)/y_test)) * 100

print("\n----- Best-of-Both-Worlds Model -----")
print("Intercept:", model.intercept_)
print("\nCoefficients:")
for col, coef in zip(cols_to_use, model.coef_):
    print(f"{col}: {coef:.4f}")

print(f"\nR²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 7. BASELINE MODEL
# --------------------------

constant_pred = np.full_like(y_test, y_train.mean())
r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 8. VISUALIZATIONS
# --------------------------

# Correlation heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Actual vs Predicted
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Actual vs Predicted")
plt.show()
# Out:
# ----- Best-of-Both-Worlds Model -----
# Intercept: 10.745519237108354
#
# Coefficients:
# As_Mean: 0.1415
# Qz_Mean: -0.0757
# S-I: 0.1030
# S-II: 0.5968
#
# R²: 0.6115
# Adjusted R²: 0.5375
# RMSE: 12.8561
# MAE: 10.4925
# MAPE: 39.31%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# --------------------------
# 1. IMPUTE MISSING VALUES
# --------------------------

as_mean_raw = df[["As:1","As:2","As:3","As:4"]].mean(axis=1)
df["As:5"] = df["As:5"].fillna(as_mean_raw)
df["As:6"] = df["As:6"].fillna(as_mean_raw)

qz_mean_raw = df[["Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6"]].mean(axis=1)
df["Qz:7"] = df["Qz:7"].fillna(qz_mean_raw)
df["Qz:8"] = df["Qz:8"].fillna(qz_mean_raw)

# --------------------------
# 2. CREATE COLLAPSED FEATURES
# --------------------------

df["As_Mean"] = df[["As:1","As:2","As:3","As:4"]].mean(axis=1)
df["Qz_Mean"] = df[["Qz:1","Qz:2","Qz:3","Qz:4","Qz:5","Qz:6"]].mean(axis=1)

# --------------------------
# 3. SELECT PREDICTORS
# --------------------------

cols_to_use = ["As_Mean", "Qz_Mean", "S-I", "S-II"]
X = df[cols_to_use]
y = df["Final"]

# --------------------------
# 4. TRAIN-TEST SPLIT
# --------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 5. POLYNOMIAL FEATURES
# --------------------------

poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# --------------------------
# 6. FIT LINEAR REGRESSION ON POLYNOMIAL FEATURES
# --------------------------

model = LinearRegression()
model.fit(X_train_poly, y_train)
y_pred = model.predict(X_test_poly)

# --------------------------
# 7. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1 - r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test_poly.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred)/y_test)) * 100

print("\n----- Best-of-Both-Worlds Polynomial Regression (Degree 2) -----")
print(f"Number of features after polynomial expansion: {X_train_poly.shape[1]}")
print(f"R²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 8. CONSTANT BASELINE MODEL
# --------------------------

constant_pred = np.full_like(y_test, y_train.mean())
r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 9. VISUALIZATIONS
# --------------------------

# Correlation heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# Actual vs Predicted
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Polynomial Regression: Actual vs Predicted")
plt.show()
# Out:
# ----- Best-of-Both-Worlds Polynomial Regression (Degree 2) -----
# Number of features after polynomial expansion: 14
# R²: 0.6105
# Adjusted R²: 0.1149
# RMSE: 12.8725
# MAE: 10.6740
# MAPE: 40.60%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# --------------------------
# 1. IMPUTE MISSING VALUES
# --------------------------

as_mean_raw = df[["As:1","As:2","As:3","As:4"]].mean(axis=1)
df["As:5"] = df["As:5"].fillna(as_mean_raw)
df["As:6"] = df["As:6"].fillna(as_mean_raw)

# --------------------------
# 2. CREATE COLLAPSED FEATURES
# --------------------------

df["As_Mean"] = df[["As:1","As:2","As:3","As:4"]].mean(axis=1)

# --------------------------
# 3. SELECT PREDICTORS (No Quizzes)
# --------------------------

cols_to_use = ["As_Mean", "S-I", "S-II"]
X = df[cols_to_use]
y = df["Final"]

# --------------------------
# 4. TRAIN-TEST SPLIT
# --------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, random_state=42
)

# --------------------------
# 5. FIT LINEAR REGRESSION
# --------------------------

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# --------------------------
# 6. METRICS
# --------------------------

def adjusted_r2(r2, n, k):
    return 1 - ((1 - r2)*(n-1)/(n-k-1))

r2 = r2_score(y_test, y_pred)
adj_r2 = adjusted_r2(r2, len(y_test), X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred)/y_test)) * 100

print("\n----- Best-of-Both-Worlds Linear Model (No Quizzes) -----")
print("Intercept:", model.intercept_)
print("\nCoefficients:")
for col, coef in zip(cols_to_use, model.coef_):
    print(f"{col}: {coef:.4f}")

print(f"\nR²: {r2:.4f}")
print(f"Adjusted R²: {adj_r2:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --------------------------
# 7. CONSTANT BASELINE MODEL
# --------------------------

constant_pred = np.full_like(y_test, y_train.mean())
r2_const = r2_score(y_test, constant_pred)
rmse_const = np.sqrt(mean_squared_error(y_test, constant_pred))

print("\n----- Constant Baseline Model -----")
print(f"R²: {r2_const:.4f}")
print(f"RMSE: {rmse_const:.4f}")

# --------------------------
# 8. VISUALIZATIONS
# --------------------------

# Correlation heatmap
plt.figure(figsize=(5, 4))
sns.heatmap(df[cols_to_use + ["Final"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap (No Quizzes)")
plt.show()

# Actual vs Predicted
plt.figure(figsize=(6, 4))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Final")
plt.ylabel("Predicted Final")
plt.title("Actual vs Predicted (No Quizzes)")
plt.show()
# Out:
# ----- Best-of-Both-Worlds Linear Model (No Quizzes) -----
# Intercept: 10.594360537235076
#
# Coefficients:
# As_Mean: 0.1215
# S-I: 0.0743
# S-II: 0.5855
#
# R²: 0.6229
# Adjusted R²: 0.5715
# RMSE: 12.6660
# MAE: 10.2966
# MAPE: 38.40%
#
# ----- Constant Baseline Model -----
# R²: -0.0011
# RMSE: 20.6386

# %%
# --------------------------
# 1. MODEL COEFFICIENTS (from your trained model)
# --------------------------

intercept = 10.594360537235076
coef_As = 0.1215
coef_SI = 0.0743
coef_SII = 0.5855

# --------------------------
# 2. FUNCTION TO PREDICT FINAL
# --------------------------

def predict_final(As_Mean, S_I, S_II):
    final_pred = intercept + coef_As*As_Mean + coef_SI*S_I + coef_SII*S_II
    return final_pred

# --------------------------
# 3. EXAMPLE USAGE: TAKE USER INPUT
# --------------------------

As_Mean = float(input("Enter average of As1–4: "))
S_I = float(input("Enter S-I score: "))
S_II = float(input("Enter S-II score: "))

predicted_final = predict_final(As_Mean, S_I, S_II)
print(f"\nPredicted Final Score: {predicted_final:.2f}")
# Out:
# Enter average of As1–4:  95
# Enter S-I score:  86.67
# Enter S-II score:  96.67
# Predicted Final Score: 85.18

# %%
df["S-II"].corr(df["S-I"])
# Out:
# np.float64(0.6570110662905726)
